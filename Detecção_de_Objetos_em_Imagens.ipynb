# %% [markdown]
# # **Detecção de Objetos com YOLOv8**

# %% [markdown]
# **Instalação da biblioteca Ultralytics**

# %%
# !pip install ultralytics==8.0.0

# %%
from IPython.display import Image
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### **Detecção de Objetos com YOLOv8**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/Palestra_CDL.jpg'
# Out:
# 2023-09-16 18:43:54.616916: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-16 18:43:55.931354: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
# 100% 21.5M/21.5M [00:01<00:00, 18.8MB/s]
#
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# image 1/1 /content/Palestra_CDL.jpg: 480x640 13 persons, 1 backpack, 1 handbag, 1 bottle, 3 chairs, 1 dining table, 2 laptops, 67.7ms
# Speed: 0.6ms pre-process, 67.7ms inference, 41.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
Image('/content/runs/detect/predict/Palestra_CDL.jpg')

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/IMG-20230913-WA0017.jpg'
# Out:
# 2023-09-16 18:45:26.558268: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-16 18:45:27.569403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# image 1/1 /content/IMG-20230913-WA0017.jpg: 480x640 17 persons, 60.1ms
# Speed: 0.5ms pre-process, 60.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
Image('/content/runs/detect/predict2/IMG-20230913-WA0017.jpg')

# %% [markdown]
# ### **Save Crop**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/Palestra_CDL.jpg' save_crop=True
# Out:
# 2023-09-16 18:48:30.736788: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-16 18:48:31.736957: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# image 1/1 /content/Palestra_CDL.jpg: 480x640 13 persons, 1 backpack, 1 handbag, 1 bottle, 3 chairs, 1 dining table, 2 laptops, 72.4ms
# Speed: 0.6ms pre-process, 72.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/IMG-20230913-WA0017.jpg' save_crop=True
# Out:
# 2023-09-16 18:49:20.331915: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-16 18:49:21.309800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# image 1/1 /content/IMG-20230913-WA0017.jpg: 480x640 17 persons, 106.7ms
# Speed: 0.6ms pre-process, 106.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
